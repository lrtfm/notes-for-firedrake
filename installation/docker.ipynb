# %% [markdown]
# # 基于 Docker 的安装

# %% [markdown]
# ## Docker

# %% [markdown]
# ### Ubuntu 上安装 docker

# %% [markdown]
# #### 启动 docker 守护进程

# %% [markdown]
# 使用docker 命令需要开启Docker 守护进程. Docker 的守护进程需要使用 root 权限开启.
#
# 由于 WSL 中的 Ubuntu 不是使用 systemd 启动的, 使用下面第一种方式会显示如下错误:
# ```txt
# `System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# ```
# 所以我们在 WSL 中需要使用第二种方式启动 Docker 守护进程.

# %% [markdown]
# 1. Ubuntu
#
# ```bash
# sudo systemctl start docker
# ```
#
# 2. Ubuntu in WSL
#
#
# ```bash
# sudo service docker start
# ```

# %% [markdown]
# #### 测试

# %% [markdown]
# 1. 查看相关信息 (输出可能会不同)
#
#     + `docker version` 输出:
#
#         ```txt
#         Client: Docker Engine - Community
#          Version:           20.10.2
#          API version:       1.41
#          Go version:        go1.13.15
#          Git commit:        2291f61
#          Built:             Mon Dec 28 16:17:43 2020
#          OS/Arch:           linux/amd64
#          Context:           default
#          Experimental:      true
#
#         Server: Docker Engine - Community
#          Engine:
#           Version:          20.10.2
#           API version:      1.41 (minimum version 1.12)
#           Go version:       go1.13.15
#           Git commit:       8891c58
#           Built:            Mon Dec 28 16:15:19 2020
#           OS/Arch:          linux/amd64
#           ...
#          docker-init:
#           Version:          0.19.0
#           GitCommit:        de40ad0
#         ```
#
#     + `docker info` 输出:
#
#         ```txt
#         Client:
#          Context:    default
#          Debug Mode: false
#          Plugins:
#           app: Docker App (Docker Inc., v0.9.1-beta3)
#           buildx: Build with BuildKit (Docker Inc., v0.5.1-docker)
#
#         Server:
#          Containers: 6
#           Running: 1
#           Paused: 0
#           Stopped: 5
#          ...
#          Docker Root Dir: /var/lib/docker
#          Debug Mode: false
#          Registry: https://index.docker.io/v1/
#          Labels:
#          Experimental: false
#          Insecure Registries:
#           127.0.0.0/8
#          Live Restore Enabled: false
#         ```
#
# 2. 拉取镜像
#
# ### MacOS 安装 Docker
#
# 请参考 https://yeasy.gitbook.io/docker_practice/install/mac

# %% [markdown]
# ## Firedrake

# %% [markdown]
# ### Firedrake 镜像
#
# #### 下载镜像
# Firedrake 官方构建完整的镜像 [firedrakeproject/firedrake](https://hub.docker.com/r/firedrakeproject/firedrake) 发布在 [docker hub (https://hub.docker.com/)](https://hub.docker.com/), 以及支持 jupyter notebook 的镜像  [firedrakeproject/firedrake-notebooks](https://hub.docker.com/r/firedrakeproject/firedrake-notebooks). 我们下载这些镜像, 然后运行即可使用.
#
# 下载镜像我们直接使用 `docker pull` 命令即可, 示例如下:
#
# 1. 下载 firedrakeproject/firedrake
#
# ```bash
# docker pull firedrakeproject/firedrake
# ```
#
# 2. 下载 firedrakeproject/firedrake-notebooks
#
# ```bash
# docker pull firedrakeproject/firedrake-notebooks
# ```
#
# 开始学习使用的话, 建议下载 firedrakeproject/firedrake-notebooks 镜像, 我们将在后面详述如何运行镜像.

# %% [markdown]
# #### 构建镜像
#
# 在编程中, 我们可能需要一些镜像中未安装的软件包, 此时我们就需要定制我们自己的镜像了. 我们可以基于 firedrake 的镜像构建新的镜像, 添加一些新的功能.

# %% [markdown]
# ##### 创建 Dockerfile
#
# 1. 新建目录 firedrake-jupyter
#
# ```
# mkdir  firedrake-jupyter
# cd firedrake-jupyter
# ```
#
# 2. 新建文件 `Dockerfile.jupyter`, 内容如下:

# %% [raw]
# # DockerFile for a firedrake + jupyter container
#
# FROM firedrakeproject/firedrake
#
# # This file was modefied by Zongze Yang (yangzongze@gmail.com)
# # based on `https://github.com/firedrakeproject/firedrake/blob/master/docker/Dockerfile.jupyter`
#
# USER firedrake
#
# WORKDIR /home/firedrake
# # Install jupyterlab and tqdm
# RUN bash -c ". /home/firedrake/firedrake/bin/activate && pip install jupyterlab tqdm"
#
# # Remove the install log.
# RUN bash -c "rm firedrake-*"
# # Put the notebooks in the working directory for the notebook server.
# RUN bash -c "cp -r firedrake/src/firedrake/docs/notebooks/* ."
# # Strip the output from the notebooks.
# RUN bash -c '. /home/firedrake/firedrake/bin/activate && for file in *.ipynb; do jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace $file; done'
#
# CMD /home/firedrake/firedrake/bin/jupyter-lab --ip 0.0.0.0 --no-browser --allow-root

# %% [markdown]
# 3. 构建镜像
#
# ```bash
# docker build --tag <tag-of-the-container> -f Dockerfile.jupyter .
# ```
#
#     比如我给这个镜像打的标签为 `lrtfm/firedrake-jupyter` 那么命令为
#
# ```
# docker build --tag lrtfm/firedrake-jupyter -f Dockerfile.jupyter .
# ```
#
#     该镜像已上传至 docker hub, 可以使用上一节介绍的下载命令下载:
#
# ```bash
# docker pull lrtfm/firedrake-jupyter
# ```

# %% [markdown]
# ### 运行镜像
#
# 这里我们将介绍 firedrake-notebooks 镜像和我们上面构建的 firedrake-jupyter 镜像的使用方法.

# %% [markdown]
# #### 镜像和容器
#
# 有两个名词需要区分一下: _镜像 (Image)_ 和 _容器 (Container)_. 他们的关系有点类似于计算机中的 _程序 (Program)_ 和 _进程 (Process)_.
#
# 我们上面下载的 `firedrakeproject/firedrake` 就是镜像. 可以通过 `docker image ls` 查看所有镜像.
# ```
# $ docker image ls
# REPOSITORY                   TAG       IMAGE ID       CREATED          SIZE
# lrtfm/firedrake-jupyter      latest    fb4c8a8d87a2   29 minutes ago   5.74GB
# lrtfm/firedrake-jupyter      test      b88daa690a72   9 hours ago      5.82GB
# firedrakeproject/firedrake   latest    203cb66fd620   2 days ago       5.64GB
# spack/tutorial               latest    ae1b12514068   12 months ago    8.94GB
# hello-world                  latest    bf756fb1ae65   19 months ago    13.3kB
# ```
#
# 像运行程序一样, 我们使用 `docker run` 可以通过一个镜像创建一个新的容器
#
# ```
# $ docker run -ti  firedrakeproject/firedrake
# ```
#
# 它的输出如下, 表明我们进入了 容器 的环境中, 这里已经可以运行 firedrake 的程序了.
# ```
# To run a command as administrator (user "root"), use "sudo <command>".
# See "man sudo_root" for details.
#
# firedrake@7223f8b352bd:~$
# ```
#
# 输入 `exit` 即可退出这个环境.
#
#
# 类似的, 可以通过 `docker container ls` 查看所有容器.
# ```
# $ docker container ls -a
# CONTAINER ID   IMAGE                        COMMAND                  CREATED              STATUS                          PORTS                     NAMES
# 7223f8b352bd   firedrakeproject/firedrake   "bash"                   About a minute ago   Exited (0) 4 seconds ago                                  angry_booth
# 27eedee6ef45   firedrakeproject/firedrake   "bash"                   About a minute ago   Exited (0) About a minute ago                             silly_hodgkin
# ef05d20b0a6e   firedrakeproject/firedrake   "bash"                   3 minutes ago        Exited (0) 2 minutes ago                                  firedrake
# b62a4a49ce89   lrtfm/firedrake-jupyter      "/bin/sh -c '/home/f…"   27 minutes ago       Up 27 minutes                   0.0.0.0:18888->8888/tcp   firedrake-jupyter
# ```
#
# 上一个命令中 `-a` 参数的作用是显示所有容器, 包括已经退出的容器, 否则只仅显示当前运行的容器.
#
#
# #### 共享主机目录到容器
#
# 由于镜像内的东西都是只读的, 你在运行它得到容器后, 可以对容器进行更改, 但对镜像本身是没有影响的. 由于容器是类似与进程的东西, 它也不是永久的, 所以我们在创建容器时一般会共享主机的文件夹给容器, 这样我们可以把程序和数据放在这个文件家中. 容器中对这个文件夹的修改在主机上是可见的, 也是可以永久留存的. 共享文件夹需要在运行 `docker run` 命令时, 使用 `-v` 选项:
#
# ```bash
# docker run -v path-to-host-fold:path-to-container-fold firedrakeproject/firedrake
# ```
#
# 如果我像把当前目录共享给容器, 容器中路径设为 `/home/firedrake/workdir`, 就可以运行如下命令:
#
# ```bash
# docker run -ti -v $(pwd):/home/firedrake/workdir  firedrakeproject/firedrake
# ```
#
# 运行后我们可以查看目录 `/home/firedrake`, 发现多了 `workdir` 目录, 其内容为主机文件夹中内容
# ```shell
# $ docker run -ti -v $(pwd):/home/firedrake/workdir  firedrakeproject/firedrake
# To run a command as administrator (user "root"), use "sudo <command>".
# See "man sudo_root" for details.
#
# firedrake@0895c511469e:~$ ls
# firedrake  firedrake-install  firedrake-install.log  workdir
# firedrake@0895c511469e:~$ ls
# firedrake  firedrake-install  firedrake-install.log  workdir
# firedrake@0895c511469e:~$ ls workdir/
# Dockerfile.jupyter  Untitled.ipynb
# ```

# %% [markdown]
# #### `docker run` 其他选项介绍
#
# 1. `-d` 在后台运行容器
# 2. `--name <the-name>` 给容器命名, 这样下次可以直接使用 `docker start <the-name>` 启动容器, 而不用重新 `docker run`. 因为容器如果绑定主机端口的话, 不删除该容器 (即使该容器已退出), 就不能使用 `docker run` 绑定该端口. 我们使用 jupyter 时需要绑定端口, 使得我们可以使用主机的浏览器访问容器中的服务, 所以我们一般第一次使用 `docker run --name <the-name> ...` 创建一个有名字的容器, 下次直接使用 `docker start <the-name>` 即可运行, 如果要停止它秩序使用 `docker stop <the-name>` 即可.
#
# 3. `-p <host-port>:<container-port>` 端口映射, 把容器的端口 <container-port> 映射到主机的端口 <host-port>. 由于上述容器如firedrakeproject/firedrake-notebooks 中的 jupyter 服务的端口为 `8888`, 这里就需要把
#     <container-port> 改为 `8888`, 而主机的端口可以任意设置, 只要没有使用过, 一般要大于 1024, 也可以设置为8888

# %% [markdown]
# #### 示例介绍

# %% [markdown]
# ##### 运行 firedrakeproject/firedrake-notebooks

# %% [markdown]
# 1. 创建名为 `firedrake-notebook` 的容器, 并绑定主机的端口 18888, (可以任意设置, 记下设置的值, 后面会用到)
# ```bash
# docker run -d -v $(pwd):/home/firedrake/workdir --name firedrake-notebook -p 18888:8888 firedrakeproject/firedrake-notebooks
# ```
#
# 2. 查看 jupyter server 的 token (后面需要用的到网页登录密码)
#
# ```
# docker logs firedrake-notebook
# ```
#
# 3. 打开浏览器输入网址 `127.0.0.1:18888 (这里18888 为上面绑定的主机端口)
#
# 4. 输入 token
#
# 至此即可在浏览器中编写和运行 Firedrake 程序了
#
# 5. 完成工作如果需要关闭 container, 运行 `docker stop firedrake-notebook` 即可
# 6. 重新打开 container, 运行 `docker start firedrake-notebook` 即可
